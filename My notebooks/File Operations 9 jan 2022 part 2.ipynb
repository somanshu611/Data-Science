# %%
import os
# different ways ot get current working directory

# %%
os.getcwd()
# Out:
# 'C:\\Users\\soman\\KNAWLEDGE'

# %%
pwd()
# Out:
# 'C:\\Users\\soman\\KNAWLEDGE'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'abc.txt',
#  'Data Visualization.ipynb',
#  'File Operations 2022 9 jan.ipynb',
#  'file sysetm( 9 Jan resource).ipynb',
#  'Function in pyton  (1).ipynb',
#  'Functions 2022 8 Jan.ipynb',
#  'Functions Part 2.1.ipynb',
#  'google.txt',
#  'iterator generator( 9 jan Resource).ipynb',
#  'Loggind&Debugging(Old).ipynb',
#  'logging',
#  'Matplotlib.ipynb',
#  'Pandas.ipynb',
#  'Python.ipynb',
#  'Seaborn 2.ipynb',
#  'Seaborn.ipynb',
#  'test.log',
#  'test.txt',
#  'test2.txt',
#  'test3.txt',
#  'Untitled.ipynb',
#  'Untitled1.ipynb',
#  'Untitled2.ipynb',
#  'Untitled3.ipynb']

# %%
# Original path : 
# You need to convert '\' to '\\' before pasting in listdir()
# os.listidr() gives all the directories in ascendidng order by name. It is really useful for finding any file which you can't 
# which you can't manually find.

os.listdir("C:\\Users\\soman\\Downloads")
# Out:
# ["'' Warrior '' Inspirational Emotional Aggressive Rap Beat War Violin Cello Hip-Hop Beat [SOLD].mp3",
#  '-HorribleSubs- Naruto Shippuuden - 418 -1080p-.mp4',
#  '-HorribleSubs- Naruto Shippuuden - 419 -1080p-.mp4',
#  '-HorribleSubs- Naruto Shippuuden - 420 -1080p-.mp4',
#  '-HorribleSubs- Naruto Shippuuden - 421 -1080p-.mp4',
#  '-Judas- Naruto - S02E13 -048-.mp4',
#  '-Judas- Naruto - S02E14 -049-.mp4',
#  '-Judas- Naruto - S02E15 -050-.mp4',
#  '-Judas- Naruto - S03E15 -098-.mp4',
#  '-Judas- Naruto - S03E16 -099-.mp4',
#  '-Judas- Naruto - S03E17 -100-.mp4',
#  '-Kametsu- Attack on Titan - 25 -BD 1080p Hi10 FLACx3- -693CED80-.mp4.sfk',
#  '-SubsPlease- Boku no Hero Academia - 96 -1080p- -FB4DC6CE-.mp4',
#  '0009-64bit_Win7_Win8_Win81_Win10_R282.exe',
#  '0009-64bit_Win7_Win8_Win81_Win10_R282_0819258904.exe',
#  '0101EX191054_EX301.pdf',
#  '0101EX191054_EX302.pdf',
#  '0101EX191054_EX303.pdf',
#  '0101EX191054_EX305.pdf',
#  '0101EX191054_EX310.pdf',
# ...

# %%
os.getcwd()
# Out:
# 'C:\\Users\\soman\\KNAWLEDGE'

# %% [markdown]
# ### ineuron kivy

# %%
import os

# %%
path = input()
# Out:
# .

# %%
os.listdir(path)
# Out:
# ['.ipynb_checkpoints',
#  '29 JAN 2022 INHERITANCE.ipynb',
#  '30 Jan 2022 FSDS polymorphism.ipynb',
#  'File Operations 2022 9 jan.ipynb',
#  'File Operations 9 jan 2022 part 2.ipynb',
#  'FSDS 15 & 16 Jan 2022.ipynb',
#  'FSDS 23 jan 2022 OOPS in python.ipynb',
#  'Functions 2022 8 Jan.ipynb',
#  'test.txt']
