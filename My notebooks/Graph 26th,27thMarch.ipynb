# %% [markdown]
#  # 26th March

# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %matplotlib inline

# %%
df = pd.DataFrame(np.random.randn(1000),columns = ['data'],index = pd.date_range('2022/03/26',periods = 1000))
df
# Out:
#                 data
# 2022-03-26 -1.800522
# 2022-03-27  0.895602
# 2022-03-28  0.839277
# 2022-03-29  0.658880
# 2022-03-30 -0.846802
# ...              ...
# 2024-12-15  0.500232
# 2024-12-16  0.569293
# 2024-12-17  0.085263
# 2024-12-18 -0.998446
# 2024-12-19  0.891996
#
# [1000 rows x 1 columns]

# %%
df.plot(figsize = (20,10))
# Out:
# <AxesSubplot:>

# %%
df = pd.read_csv('https://raw.githubusercontent.com/venky14/Machine-Learning-with-Iris-Dataset/master/Iris.csv')
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.plot(figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df.drop(['Id'],axis=1,inplace=True)

# %%
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.plot(figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
df.plot(figsize=(20,10),kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
df.plot(figsize=(20,10),kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.head(50).plot(figsize=(20,10),kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
df[:50].plot(figsize=(20,10),kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
df[5:15].plot(figsize=(20,10),kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
df[5:15].plot(figsize=(20,10),kind = 'box')
# Out:
# <AxesSubplot:>

# %%
df[5:15].plot(figsize=(20,10),kind = 'kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df.iloc[[1]].plot(figsize=(20,10),kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
df.iloc[[1]].plot(figsize=(20,10),kind = 'barh')
# Out:
# <AxesSubplot:>

# %%
df.iloc[5:11].plot(figsize=(20,10),kind = 'barh')
# Out:
# <AxesSubplot:>

# %%
df.plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['SepalLengthCm'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['SepalLengthCm'].plot(kind='hist',orientation='horizontal')
# Out:
# <AxesSubplot:xlabel='Frequency'>

# %%
# Here, we are calling hist as a function, in plot() hist was a argument.
df.hist(figsize=(20,10),color='g',alpha=0.3)
# Out:
# array([[<AxesSubplot:title={'center':'SepalLengthCm'}>,
#         <AxesSubplot:title={'center':'SepalWidthCm'}>],
#        [<AxesSubplot:title={'center':'PetalLengthCm'}>,
#         <AxesSubplot:title={'center':'PetalWidthCm'}>]], dtype=object)

# %% [markdown]
# # Box Plot

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df.plot(kind = 'box',figsize=(20,10),color = {'boxes':'g','whiskers':'r'})
# Out:
# <AxesSubplot:>

# %%
df.plot(kind = 'box',figsize=(20,10),color = {'boxes':'g','whiskers':'r'},vert=False)
# Out:
# <AxesSubplot:>

# %%
df.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %%
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.plot(kind='area',figsize=(20,10),alpha=0.5)
# Exactly same to line graph, instead it shows area too.
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='area',figsize=(20,10),alpha=0.5,stacked=False)
# Out:
# <AxesSubplot:>

# %%
# Scatter plot
# For finding correlation
df.plot.scatter(x='SepalLengthCm',y='PetalLengthCm')
# strong relationship
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='PetalLengthCm'>

# %%
df.plot.scatter(x='SepalLengthCm',y='PetalWidthCm')
# too scattered
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='PetalWidthCm'>

# %%
df.plot.scatter(x='SepalLengthCm',y='PetalLengthCm',c='SepalWidthCm',figsize=(20,10),s=200)
# s = size of dots
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='PetalLengthCm'>

# %%
# you can also write 's' as a function of other variable.
# lIke this : 
df.plot.scatter(x='SepalLengthCm',y='PetalLengthCm',c='SepalWidthCm',figsize=(20,10),s=df['PetalWidthCm']*300)
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='PetalLengthCm'>

# %%
df.plot.hexbin(x='SepalLengthCm',y='PetalLengthCm',gridsize=10,C='PetalWidthCm')
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='PetalLengthCm'>

# %%
df1 = df.drop(columns='Species').iloc[0]

# %%
df1.plot(kind='pie',figsize=(20,10))
# Out:
# <AxesSubplot:ylabel='0'>

# %% [markdown]
# # Plotly library

# %%
# !pip install plotly
# Out:
# ^C

# %%
# !pip install cufflinks
# Out:
# ...
# ^C

# %%
# !pip install chart_studio
# Out:
# ...
#   Created wheel for retrying: filename=retrying-1.3.3-py3-none-any.whl size=11448 sha256=5145705c2955d67445ce1ddcf17838b2fbf93232fdc73cb754df14b4aac7e7e3
#   Stored in directory: c:\users\soman\appdata\local\pip\cache\wheels\ce\18\7f\e9527e3e66db1456194ac7f61eb3211068c409edceecff2d31
# Successfully built retrying
# ...

# %%
import plotly as ply
import cufflinks as cf
# offline version of plotly is cufflinks

# %%
df.iplot()
# Was running ininitely
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4648/4163631973.py in <module>
# ----> 1 df.iplot()
#
# ~\CODE_STUFF\Anaconda3\lib\site-packages\cufflinks\plotlytools.py in _iplot(self, kind, data, layout, filename, sharing, title, xTitle, yTitle, zTitle, theme, colors, colorscale, fill, width, dash, mode, interpolation, symbol, size, barmode, sortbars, bargap, bargroupgap, bins, histnorm, histfunc, orientation, boxpoints, annotations, keys, bestfit, bestfit_colors, mean, mean_colors, categories, x, y, z, text, gridcolor, zerolinecolor, margin, labels, values, secondary_y, secondary_y_title, subplots, shape, error_x, error_y, error_type, locations, lon, lat, asFrame, asDates, asFigure, asImage, dimensions, asPlot, asUrl, online, **kwargs)
#    1214                 return Figure(figure)
#    1215         else:
# ...

# %%
# Workaround for df.iplot() not working
cf.go_offline()

df.iplot()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="9e55fc87-fa9c-4c95-a2f7-1441f5059367" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.drop(columns=['Id'],inplace=True)

# %%
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.iplot()
# Out:
# <div>                            <div id="e66ce719-2a5c-4ce1-bbb0-0a659dc377f1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(x='SepalLengthCm',y='PetalLengthCm')
# line graph is default
# Out:
# <div>                            <div id="2c41121f-23a4-4351-a79f-01ddf106fcca" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(x='SepalLengthCm',y='PetalLengthCm',mode='markers')
# Out:
# <div>                            <div id="a270848d-aba1-41ab-9f85-d8a7ce290c1d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(x='SepalLengthCm',y='PetalLengthCm',mode='markers',kind='scatter')
# Out:
# <div>                            <div id="a6b377f5-7e10-49c2-8b8d-2ba8f7a626e4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind='scatter',mode='markers')
# Out:
# <div>                            <div id="9c1cb491-7c6c-4def-a360-debaf5c1a7f8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind='scatter',mode='markers',size=5)
# Out:
# <div>                            <div id="9a2d7a56-8584-4f56-ba40-1137a9302841" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind = 'bubble',x='SepalLengthCm',y='PetalLengthCm',size='SepalWidthCm')
# Out:
# <div>                            <div id="0f236dfa-ff4e-4fe4-afc9-fdd1ecd5208d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.scatter_matrix()
# Out:
# <div>                            <div id="34f13547-1334-4d79-b754-a1887dd4fa56" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot()
