# %%
## 26th Feb material, i didn't watch the lecture because i already knew pandas basic.

# %%
## From here, 27th Feb material

# %%
import pandas as pd

# %%
# pd.read_html() only scraps tabular data on a website
# returns a list of all tables(dataframe) presnet on the website
df = pd.read_html('https://www.basketball-reference.com/leagues/NBA_2015_totals.html')

# %%
type(df)
# Out:
# list

# %%
len(df)
# Out:
# 1

# %%
df[0]
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
type(df[0])
# Out:
# pandas.core.frame.DataFrame

# %%
df1=df[0]

# %%
df1.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
df1.head(d)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9228/2298858394.py in <module>
# ----> 1 df1.head(d)
#
# NameError: name 'd' is not defined

# %%
df1.tail(10)

# %%
df1.dtypes

# %%
# Filter out columnsdf1
df1[['Age','GS']]

# %%
df1.to_csv('NBA.csv')

# %%
ls

# %%
df1.to_csv('NBA.csv',index=False)

# %%
ls

# %%
l = pd.read_html('https://stats.espncricinfo.com/ci/engine/records/averages/batting_bowling_by_team.html?id=14209;team=6;type=series')

# %%
len(l)

# %%
l

# %%
l[0].to_csv('cric.csv',index=False)

# %%
l[1]

# %%
l[2]

# %%
d = """
{
"name" : "somanshu Sharma",
"email_id" : "somanshusharma611@gmail.com",
"tech" : ["ML","DL","CV"],
"platform" : ["techneuron","oneneuron","kidsneuron"]
}"""

# %%
pd.DataFrame(d)

# %%
import json

# %%
type(d)

# %%
result = json.loads(d)

# %%
result

# %%
type(result)

# %%
pd.DataFrame(result)
# Flattening of the data can be seen because of unequal length of lists. If all the list values in a dictionary are of 
# equal lenght then it will work.

# %%
pd.read_json(result)

# %%
# for deleting a key in dict
del result['name']

# %%
result

# %%
d = {"packetType":"D","data":{"checkEngineLightFlag":"F","batteryVoltageStableTime":0,"batteryVoltageStable":"0","batteryVoltageOff":"12.42","batteryCrankParamTN":"-0.08","batteryCrankParamVN":"0.00","batteryCrankParamTP":"-0.08","batteryCrankParamVP":"0.00","batteryCrankParamTT":"-0.00008","batteryCrankParamV0":"0.00","batteryVoltageMaxOn":"13.05","batteryVoltageMinOn":"12.97","batteryVoltageMaxOff":"12.46","batteryVoltageMinOff":"12.36","batteryVoltageOnAverage":"13.02","engineLoadMax":"84","engineLoadAverage":"39.98","rpmMax":"3487","rpmAverage":"1431.29","gpsSpeedAverage":"21.99","vssMax":"53.44","vssAverage":"23.06","tcuTemperatureMin":"82.40","tcuTemperatureMax":"109.40","tcuTemperatureAverage":"104.87","coolantMin":"158.00","coolantMax":"188.60","coolantAverage":"180.20","packetStartLocal":1508143346000,"tripStartLocal":1508143346000,"milIndicator":"F","monitorsNotReady":0,"imei":"60DF5417","gatewayTs":1515613306592,"diagnosticTroubleCodeData":[],"diagnosticPidData":[[64768,47,100],[64768,1,517376],[64800,1,262144],[64768,5,125]]},"header":{"iwrapVer":"1.9.20","sourceSystem":"CDP","configVer":"1.1","oemName":"HUM","unitType":0,"cpVer":"7.50.1.9","igpsVer":"1.3.7","messageType":"Notification","pomVer":"1.0","headerVer":"V6","timestamp":0,"deviceType":"InDrive","visorVer":"1.4.35","transactionId":"53098471-7787-4160-94b3-cd69dcc70416","deviceSerialNo":"60DF5417","subOrganization":"HUM","organization":"HUM","imei":"60DF5417","operation":"Notification"}}

# %%
d1 = d['data']

# %%
df = pd.DataFrame(d1)

# %%
url = "https://api.github.com/repos/pandas-dev/pandas/issues"

# %%
pd.read_json(url)

# %%
import requests

# %%
data = requests.get(url)

# %%
# 200 -> means successful request

# %%
data1 = data.json()

# %%
data1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9228/2296849294.py in <module>
# ----> 1 data1
#
# NameError: name 'data1' is not defined

# %%
len(data1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9228/3624228275.py in <module>
# ----> 1 len(data1)
#
# NameError: name 'data1' is not defined

# %%
data1[0]['user']['id']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9228/1614270979.py in <module>
# ----> 1 data1[0]['user']['id']
#
# NameError: name 'data1' is not defined

# %%
data1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9228/2296849294.py in <module>
# ----> 1 data1
#
# NameError: name 'data1' is not defined

# %%
for i in range(len(data1)) : 
    print(data1[i]['user']['id'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9228/3470681067.py in <module>
# ----> 1 for i in range(len(data1)) :
#       2     print(data1[i]['user']['id'])
#
# NameError: name 'data1' is not defined

# %%
pd.DataFrame(data1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9228/2597260155.py in <module>
# ----> 1 pd.DataFrame(data1)
#
# NameError: name 'data1' is not defined

# %%
df2 = pd.DataFrame(data1, columns = ['id','url','repository_url','labels_url','user'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9228/3826743520.py in <module>
# ----> 1 df2 = pd.DataFrame(data1, columns = ['id','url','repository_url','labels_url','user'])
#
# NameError: name 'data1' is not defined

# %%
df2.to_csv('jsonresponse.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9228/1191992361.py in <module>
# ----> 1 df2.to_csv('jsonresponse.csv')
#
# NameError: name 'df2' is not defined

# %%
df2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9228/3882145664.py in <module>
# ----> 1 df2
#
# NameError: name 'df2' is not defined

# %%
len(df2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9228/1830384054.py in <module>
# ----> 1 len(df2)
#
# NameError: name 'df2' is not defined

# %%
df2['user'][0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9228/2475933444.py in <module>
# ----> 1 df2['user'][0]
#
# NameError: name 'df2' is not defined

# %%
if 'id' in df2.columns : 
    print("yes")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9228/3208734310.py in <module>
# ----> 1 if 'id' in df2.columns :
#       2     print("yes")
#
# NameError: name 'df2' is not defined

# %%
df3= pd.DataFrame

# %%
# wrong approach, because 'id' is present already in df2.columns and also present in df2['user'][i]
# for i in range(len(df2)) :
#     for j in df2['user'][i] : 
#         # j is kyes in df2['user'][i]
#         if not(j in df3.columns) :
#             df2[j] = pd.NaT
#         df3[j][i] = df2['user'][i][j]

# %%
df2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9228/3882145664.py in <module>
# ----> 1 df2
#
# NameError: name 'df2' is not defined

# %%
df3 = pd.DataFrame( )

# %%
df3
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(len(df2)) : 
    df3 = df3.append(df2['user'][i],ignore_index = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9228/956749036.py in <module>
# ----> 1 for i in range(len(df2)) :
#       2     df3 = df3.append(df2['user'][i],ignore_index = True)
#
# NameError: name 'df2' is not defined

# %%
df3
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df4 = pd.concat([df2,df3],axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9228/1190359099.py in <module>
# ----> 1 df4 = pd.concat([df2,df3],axis=1)
#
# NameError: name 'df2' is not defined

# %%
df4
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9228/1306066122.py in <module>
# ----> 1 df4
#
# NameError: name 'df4' is not defined

# %% [markdown]
# ## day 3, 5 march pandas from here

# %%
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv'

# %%
df = pd.read_csv(url)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
 df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# considers only numerical features
f.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9228/3194996172.py in <module>
#       1 # considers only numerical features
# ----> 2 f.describe()
#
# NameError: name 'f' is not defined

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.dtypes == object
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
 # series acts like a list
type(df.dtypes)
# Out:
# pandas.core.series.Series

# %%
df.dtypes[df.dtypes == "object"]
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %%
p = [1,2,3,4,5,5,5,34,2,3,4,32,"sudh","kumar"]

# %%
p[4]
# Out:
# 5

# %%
# why is the output not as same as sudhanshu's one?
p[p==5]
# Out:
# 1

# %%
col_names = df.dtypes[df.dtypes == 'object'].index

# %%
df[col_names]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
# .describe() can give stats for categorical data but you will have to filter out categorically data first and then use
# .describe() on it.
df[col_names].describe()
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
# pandas profiling is way more better

# %%
# series are just like list
# slcing operations
df['Name'][0:15]
# Out:
# 0                               Braund, Mr. Owen Harris
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                Heikkinen, Miss. Laina
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                              Allen, Mr. William Henry
# 5                                      Moran, Mr. James
# 6                               McCarthy, Mr. Timothy J
# 7                        Palsson, Master. Gosta Leonard
# 8     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                   Nasser, Mrs. Nicholas (Adele Achem)
# 10                      Sandstrom, Miss. Marguerite Rut
# 11                             Bonnell, Miss. Elizabeth
# 12                       Saundercock, Mr. William Henry
# 13                          Andersson, Mr. Anders Johan
# 14                 Vestrom, Miss. Hulda Amanda Adolfina
# Name: Name, dtype: object

# %%
df['Name'][0:15:2]
# jump of 2
# Out:
# 0                               Braund, Mr. Owen Harris
# 2                                Heikkinen, Miss. Laina
# 4                              Allen, Mr. William Henry
# 6                               McCarthy, Mr. Timothy J
# 8     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 10                      Sandstrom, Miss. Marguerite Rut
# 12                       Saundercock, Mr. William Henry
# 14                 Vestrom, Miss. Hulda Amanda Adolfina
# Name: Name, dtype: object

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Age'].isnull() == True
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888     True
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
df[df['Age'].isnull() == True].index
# Out:
# Int64Index([  5,  17,  19,  26,  28,  29,  31,  32,  36,  42,
#             ...
#             832, 837, 839, 846, 849, 859, 863, 868, 878, 888],
#            dtype='int64', length=177)

# %%
len(df[df['Age'].isnull() == True].index)
# Out:
# 177

# %%
ind = df[df['Age'].isnull() == True].index

# %%
df.loc[ind]
# All the records where age == null
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
df[df['Age'].isnull() == True]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
df['Fare']
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: Fare, Length: 891, dtype: float64

# %%
max(df['Fare'])
# Out:
# 512.3292

# %%
df['Fare'] == max(df['Fare'])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Fare, Length: 891, dtype: bool

# %%
df[df['Fare'] == max(df['Fare'])]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C

# %%
# 5th march task easy
1 . Find out how many male and female passenger was onboarded .
2. how many survived we have .
3. how many casuality we have 
4 . what is name of a person who is the eldest one . 
5 . how many passenger do we have in first , second and third class 
6. how many person we have whose name starts with "s"
7. try to create a new column which is a summation  of "SibSp" and "parch"
8 . how many person do we have below age of 25 .
9 . how many person died whose age was less then 40 
10 . from a  cabin column seperate text and numeric value .
# Out:
#   File "C:\Users\soman\AppData\Local\Temp/ipykernel_9228/1243596149.py", line 2
#     1 . Find out how many male and female passenger was onboarded .
#              ^
# SyntaxError: invalid syntax

# %%
dataset link - https://archive.ics.uci.edu/ml/datasets/Bank+Marketing
# Out:
#   File "C:\Users\soman\AppData\Local\Temp/ipykernel_9228/1515213266.py", line 1
#     dataset link - https://archive.ics.uci.edu/ml/datasets/Bank+Marketing
#             ^
# SyntaxError: invalid syntax

# %%
import pandas as pd

# %%
df = pd.read_csv('C:\\Users\\soman\\Downloads\\bank\\bank.csv',sep=';')

# %%
df
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
1 . how many campaign available in this dataset . 
2 . how many users do we have with housing and personal loan . 
3. how many person do we have whose age is 60+ . 
4 . in which month we have trageted most of the customer . 
5 . which mode of call is giving you more result
6 . how many enterpeures do we have in this list  
7 . how many customers do we have with negative balance 
8. prepare a group of data based on education level . 


https://codeshare.io/X8PY8Y
# Out:
#   File "C:\Users\soman\AppData\Local\Temp/ipykernel_9228/2141618197.py", line 1
#     1 . how many campaign available in this dataset .
#             ^
# SyntaxError: invalid syntax

# %%
# the solutions to both these tasks were dicussed on 6th march
# For solutions i've made another jupyter notebook in git repositories folder

# %% [markdown]
# # 6th march

# %%
# Sudhanshu sir discussed previous class tasks and gave new task of resume parsing.

# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.dropna()
# drops NA values
# inplace = false is default
# axis = 0 is default, meaning rows will be deleted, if axis = 1, then row number won't change, columns will be dropped instead.
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# no change on original dataframe
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df = df = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')
df.dropna(axis=1)
# As it can be seen, only 9 columns are left now. rows are unchanged.
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris    male      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                               Heikkinen, Miss. Laina  female      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                             Allen, Mr. William Henry    male      0      0
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Embarked'].isnull().value_counts()
# Out:
# False    889
# True       2
# Name: Embarked, dtype: int64

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df2 = df.dropna(axis=1,thresh=880)
# thresh requries minimum non-NA values

# %%
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris    male      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                               Heikkinen, Miss. Laina  female      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                             Allen, Mr. William Henry    male      0      0
# ...

# %%
df2.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       2
# dtype: int64

# %%
# df.dropna(how)
# how can have two values : 'any','all'
# any : any row or column that has nan value,drop it
# all : if all values are nan then drop
df.dropna(axis=1,how='all')

# you can see no change in dataframe
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.fillna(value='somanshu')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex       Age  \
# 0                              Braund, Mr. Owen Harris    male      22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      38.0
# 2                               Heikkinen, Miss. Laina  female      26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      35.0
# 4                             Allen, Mr. William Henry    male      35.0
# ..                                                 ...     ...       ...
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.fillna(value=df['Age'].mean())
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
# We won't be filling categorical values with mean, or filling values with average of another column. This was just a demo.
# As we move forward, we'll learn different ways we can fill nan values.
# KNN imputation,is the most effective one, for filling na values, we'll learn it later

# %%
df.groupby('Survived').describe()
# Out:
#          PassengerId                                                     \
#                count        mean         std  min     25%    50%    75%
# Survived
# 0              549.0  447.016393  260.640469  1.0  211.00  455.0  675.0
# 1              342.0  444.368421  252.358840  2.0  250.75  439.5  651.5
#
#                 Pclass            ... Parch        Fare                        \
#             max  count      mean  ...   75%  max  count       mean        std
# Survived                          ...
# 0         891.0  549.0  2.531876  ...   0.0  6.0  549.0  22.117887  31.388207
# 1         890.0  342.0  1.950292  ...   1.0  5.0  342.0  48.395408  66.596998
#
#
#           min      25%   50%   75%       max
# Survived
# 0         0.0   7.8542  10.5  26.0  263.0000
# 1         0.0  12.4750  26.0  57.0  512.3292
#
# [2 rows x 48 columns]

# %%
df.groupby('Survived').describe()['PassengerId']
# Out:
#           count        mean         std  min     25%    50%    75%    max
# Survived
# 0         549.0  447.016393  260.640469  1.0  211.00  455.0  675.0  891.0
# 1         342.0  444.368421  252.358840  2.0  250.75  439.5  651.5  890.0

# %%
# Transposing of dataframe, rotating the axis
df.groupby('Survived').describe()['PassengerId'].T
# Out:
# Survived           0           1
# count     549.000000  342.000000
# mean      447.016393  444.368421
# std       260.640469  252.358840
# min         1.000000    2.000000
# 25%       211.000000  250.750000
# 50%       455.000000  439.500000
# 75%       675.000000  651.500000
# max       891.000000  890.000000

# %%
df.T
# Out:
#                                  0    \
# PassengerId                        1
# Survived                           0
# Pclass                             3
# Name         Braund, Mr. Owen Harris
# Sex                             male
# Age                             22.0
# SibSp                              1
# Parch                              0
# Ticket                     A/5 21171
# Fare                            7.25
# Cabin                            NaN
# Embarked                           S
#
#                                                            1    \
# PassengerId                                                  2
# Survived                                                     1
# Pclass                                                       1
# Name         Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex                                                     female
# Age                                                       38.0
# ...

# %%
# row wise(axis=0) concatenation
# pd.concat([df_1,df_2,.....])

# %%
# Bank Data from 5th March Task
df1 = pd.read_csv('C:\\Users\\soman\\Downloads\\bank\\bank.csv',sep=';')

# %%
df1
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
l = []
for i in df1['education'].unique() :
    l.append(df1[df1['education'] == i])

# %%
df2 = l[2]

# %%
df3 = l[3]

# %%
df2 = df2.head()
df3 = df3.head()

# %%
df2
# Out:
#    age            job  marital education default  balance housing loan  \
# 2   35     management   single  tertiary      no     1350     yes   no
# 3   30     management  married  tertiary      no     1476     yes  yes
# 5   35     management   single  tertiary      no      747      no   no
# 6   36  self-employed  married  tertiary      no      307     yes   no
# 8   41   entrepreneur  married  tertiary      no      221     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 5  cellular   23   feb       141         2    176         3  failure  no
# 6  cellular   14   may       341         1    330         2    other  no
# 8   unknown   14   may        57         2     -1         0  unknown  no

# %%
df3
# Out:
#      age          job   marital education default  balance housing loan  \
# 20    38   management  divorced   unknown      no        0     yes   no
# 27    67      retired   married   unknown      no      696      no   no
# 49    61       admin.   married   unknown      no     4629     yes   no
# 132   43  blue-collar   married   unknown     yes     -715     yes   no
# 133   48       admin.   married   unknown      no        0     yes   no
#
#        contact  day month  duration  campaign  pdays  previous poutcome    y
# 20    cellular   18   nov        96         2     -1         0  unknown   no
# 27   telephone   17   aug       119         1    105         2  failure   no
# 49    cellular   27   jan       181         1     92         1  success  yes
# 132    unknown   30   may        67         3     -1         0  unknown   no
# 133   cellular    8   may        85         1    168         2  failure   no

# %%
# row wise concatenation of dataframes using pandas
pd.concat([df2,df3])
# Out:
#      age            job   marital education default  balance housing loan  \
# 2     35     management    single  tertiary      no     1350     yes   no
# 3     30     management   married  tertiary      no     1476     yes  yes
# 5     35     management    single  tertiary      no      747      no   no
# 6     36  self-employed   married  tertiary      no      307     yes   no
# 8     41   entrepreneur   married  tertiary      no      221     yes   no
# 20    38     management  divorced   unknown      no        0     yes   no
# 27    67        retired   married   unknown      no      696      no   no
# 49    61         admin.   married   unknown      no     4629     yes   no
# 132   43    blue-collar   married   unknown     yes     -715     yes   no
# 133   48         admin.   married   unknown      no        0     yes   no
#
#        contact  day month  duration  campaign  pdays  previous poutcome    y
# 2     cellular   16   apr       185         1    330         1  failure   no
# ...

# %%
# seleting only few column from data set
df2 = df2[['age','job','marital']]

# note that this is wrong :
# df2 = df2['age','job','marital']

# %%
df2
# Out:
#    age            job  marital
# 2   35     management   single
# 3   30     management  married
# 5   35     management   single
# 6   36  self-employed  married
# 8   41   entrepreneur  married

# %%
df3 = df3[['age','job','marital']]
df3
# Out:
#      age          job   marital
# 20    38   management  divorced
# 27    67      retired   married
# 49    61       admin.   married
# 132   43  blue-collar   married
# 133   48       admin.   married

# %%
# columns wise concatenation, axis = 1
df4 = pd.concat([df2,df3],axis=1)

# This looks like union operation in sql, but it's not really the same. There's a difference that sudh talked about, i.e,
# if the condition  was on indexes, then it would have been a union operation, but it's not. This is what sudh said, but i didn't understand.

# %%
df4
# Out:
#       age            job  marital   age          job   marital
# 2    35.0     management   single   NaN          NaN       NaN
# 3    30.0     management  married   NaN          NaN       NaN
# 5    35.0     management   single   NaN          NaN       NaN
# 6    36.0  self-employed  married   NaN          NaN       NaN
# 8    41.0   entrepreneur  married   NaN          NaN       NaN
# 20    NaN            NaN      NaN  38.0   management  divorced
# 27    NaN            NaN      NaN  67.0      retired   married
# 49    NaN            NaN      NaN  61.0       admin.   married
# 132   NaN            NaN      NaN  43.0  blue-collar   married
# 133   NaN            NaN      NaN  48.0       admin.   married

# %%
df4['age']
# Out:
#       age   age
# 2    35.0   NaN
# 3    30.0   NaN
# 5    35.0   NaN
# 6    36.0   NaN
# 8    41.0   NaN
# 20    NaN  38.0
# 27    NaN  67.0
# 49    NaN  61.0
# 132   NaN  43.0
# 133   NaN  48.0

# %%
# iloc takes integer inbuilt index location
# loc takes name 
df4.iloc[:,3]

# here, the question was to fetch 2nd age column
# Out:
# 2       NaN
# 3       NaN
# 5       NaN
# 6       NaN
# 8       NaN
# 20     38.0
# 27     67.0
# 49     61.0
# 132    43.0
# 133    48.0
# Name: age, dtype: float64

# %%
df4.iloc[:,[3,4]]
# Out:
#       age          job
# 2     NaN          NaN
# 3     NaN          NaN
# 5     NaN          NaN
# 6     NaN          NaN
# 8     NaN          NaN
# 20   38.0   management
# 27   67.0      retired
# 49   61.0       admin.
# 132  43.0  blue-collar
# 133  48.0       admin.

# %%
df4.iloc[[8,9],[3,4]]
# Out:
#       age          job
# 132  43.0  blue-collar
# 133  48.0       admin.

# %%
# for fetching using index name in the first column
df4.loc[[8,49],['age']]
# Out:
#      age   age
# 8   41.0   NaN
# 49   NaN  61.0

# %%
df3
# Out:
#      age          job   marital
# 20    38   management  divorced
# 27    67      retired   married
# 49    61       admin.   married
# 132   43  blue-collar   married
# 133   48       admin.   married

# %%
df3.loc[[27,49],['job','marital']]
# Out:
#         job  marital
# 27  retired  married
# 49   admin.  married

# %%
# same thing using iloc
df3.iloc[[1,2],[1,2]]
# Out:
#         job  marital
# 27  retired  married
# 49   admin.  married

# %%
df3
# Out:
#      age          job   marital
# 20    38   management  divorced
# 27    67      retired   married
# 49    61       admin.   married
# 132   43  blue-collar   married
# 133   48       admin.   married

# %%
df2
# Out:
#    age            job  marital
# 2   35     management   single
# 3   30     management  married
# 5   35     management   single
# 6   36  self-employed  married
# 8   41   entrepreneur  married

# %%
# merge operation is exactly like sql union operation

# 'on' means on which do you want to merge
pd.merge(df2,df3,on='job')
# Out:
#    age_x         job marital_x  age_y marital_y
# 0     35  management    single     38  divorced
# 1     30  management   married     38  divorced
# 2     35  management    single     38  divorced

# %%
# left -> take everything from left and intersection between left and right
# right -> take everything from right and intersection between left and right
# outer - > takes everything
# inner -> takes only the intersection part
pd.merge(df2,df3,on='job',how='left')

# concat() only appens the data horizontally and vertically, merge and concat are verydifferent
# Out:
#    age_x            job marital_x  age_y marital_y
# 0     35     management    single   38.0  divorced
# 1     30     management   married   38.0  divorced
# 2     35     management    single   38.0  divorced
# 3     36  self-employed   married    NaN       NaN
# 4     41   entrepreneur   married    NaN       NaN

# %%
df2.join(df3,on = 'job')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9228/2190125094.py in <module>
# ----> 1 df2.join(df3,on = 'job')
#
# ~\CODE_STUFF\Anaconda3\lib\site-packages\pandas\core\frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    9097         5  K5  A5  NaN
#    9098         """
# -> 9099         return self._join_compat(
#    9100             other, on=on, how=how, lsuffix=lsuffix, rsuffix=rsuffix, sort=sort
#    9101         )
#
# ~\CODE_STUFF\Anaconda3\lib\site-packages\pandas\core\frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    9128                     sort=sort,
#    9129                 )
# -> 9130             return merge(
#    9131                 self,
#    9132                 other,
#
# ...

# %%
# difference between merge and join is, that in join you don't always need to specify 'on'.

# 'merge' is more feasible
